# %%
import healpy as hp
import numpy as np
import matplotlib.pyplot as plt

from glob import glob

from mapFunctions import getMap

# %%
# All months will be in displayed with a 'signal' map type

# %% [markdown]
# Map for 2021 (all months combined)

# %%
# Test for significance plot
map_location = '/data/user/fmcnally/anisotropy/maps/IC86-2021'
# for month in range(13):
solar_maps = sorted(glob(f'{map_location}/*solar_????-{month}-??.fits'))
m = getMap(solar_maps, mapName='signal', smooth=5, verbose=False, mask=True)
hp.mollview(m)
plt.show()
# print(solar_maps)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-3-b1e0b304ca5b> in <module>
#       2 map_location = '/data/user/fmcnally/anisotropy/maps/IC86-2021'
#       3 # for month in range(13):
# ----> 4 solar_maps = sorted(glob(f'{map_location}/*solar_????-{month}-??.fits'))
#       5 m = getMap(solar_maps, mapName='signal', smooth=5, verbose=False, mask=True)
#       6 hp.mollview(m)
#
# NameError: name 'month' is not defined

# %% [markdown]
# January

# %%
# Test for significance plot
map_location = '/data/user/fmcnally/anisotropy/maps/IC86-2021'
solar_maps = sorted(glob(f'{map_location}/*solar_????-01-??.fits'))
# print(solar_maps)

# %%
m = getMap(solar_maps, mapName='signal', smooth=5, verbose=False, mask=True)

# %%
hp.mollview(m)
plt.show()

# %% [markdown]
# February

# %%
# Test for significance plot
map_location = '/data/user/fmcnally/anisotropy/maps/IC86-2021'
solar_maps = sorted(glob(f'{map_location}/*solar_????-02-??.fits'))
# print(solar_maps)

# %%
m = getMap(solar_maps, mapName='signal', smooth=5, verbose=False, mask=True)

# %%
hp.mollview(m)
plt.show()

# %% [markdown]
# March

# %%
# Test for significance plot
map_location = '/data/user/fmcnally/anisotropy/maps/IC86-2021'
solar_maps = sorted(glob(f'{map_location}/*solar_????-03-??.fits'))
# print(solar_maps)

# %%
m = getMap(solar_maps, mapName='signal', smooth=5, verbose=False, mask=True)

# %%
hp.mollview(m)
plt.show()

# %% [markdown]
# April

# %%
# Test for significance plot
map_location = '/data/user/fmcnally/anisotropy/maps/IC86-2021'
solar_maps = sorted(glob(f'{map_location}/*solar_????-04-??.fits'))
print(solar_maps)
# Out:
# ['/data/user/fmcnally/anisotropy/maps/IC86-2021/IC86-2021_24H_solar_2022-04-01.fits', '/data/user/fmcnally/anisotropy/maps/IC86-2021/IC86-2021_24H_solar_2022-04-02.fits', '/data/user/fmcnally/anisotropy/maps/IC86-2021/IC86-2021_24H_solar_2022-04-03.fits', '/data/user/fmcnally/anisotropy/maps/IC86-2021/IC86-2021_24H_solar_2022-04-04.fits', '/data/user/fmcnally/anisotropy/maps/IC86-2021/IC86-2021_24H_solar_2022-04-05.fits', '/data/user/fmcnally/anisotropy/maps/IC86-2021/IC86-2021_24H_solar_2022-04-06.fits', '/data/user/fmcnally/anisotropy/maps/IC86-2021/IC86-2021_24H_solar_2022-04-07.fits', '/data/user/fmcnally/anisotropy/maps/IC86-2021/IC86-2021_24H_solar_2022-04-08.fits', '/data/user/fmcnally/anisotropy/maps/IC86-2021/IC86-2021_24H_solar_2022-04-09.fits', '/data/user/fmcnally/anisotropy/maps/IC86-2021/IC86-2021_24H_solar_2022-04-10.fits', '/data/user/fmcnally/anisotropy/maps/IC86-2021/IC86-2021_24H_solar_2022-04-11.fits', '/data/user/fmcnally/anisotropy/maps/IC86-2021/IC86-2021_24H_solar_2022-04-12.fits', '/data/user/fmcnally/anisotropy/maps/IC86-2021/IC86-2021_24H_solar_2022-04-13.fits', '/data/user/fmcnally/anisotropy/maps/IC86-2021/IC86-2021_24H_solar_2022-04-14.fits', '/data/user/fmcnally/anisotropy/maps/IC86-2021/IC86-2021_24H_solar_2022-04-15.fits', '/data/user/fmcnally/anisotropy/maps/IC86-2021/IC86-2021_24H_solar_2022-04-16.fits', '/data/user/fmcnally/anisotropy/maps/IC86-2021/IC86-2021_24H_solar_2022-04-17.fits', '/data/user/fmcnally/anisotropy/maps/IC86-2021/IC86-2021_24H_solar_2022-04-18.fits', '/data/user/fmcnally/anisotropy/maps/IC86-2021/IC86-2021_24H_solar_2022-04-19.fits', '/data/user/fmcnally/anisotropy/maps/IC86-2021/IC86-2021_24H_solar_2022-04-20.fits', '/data/user/fmcnally/anisotropy/maps/IC86-2021/IC86-2021_24H_solar_2022-04-21.fits', '/data/user/fmcnally/anisotropy/maps/IC86-2021/IC86-2021_24H_solar_2022-04-22.fits', '/data/user/fmcnally/anisotropy/maps/IC86-2021/IC86-2021_24H_solar_2022-04-23.fits', '/data/user/fmcnally/anisotropy/maps/IC86-2021/IC86-2021_24H_solar_2022-04-24.fits', '/data/user/fmcnally/anisotropy/maps/IC86-2021/IC86-2021_24H_solar_2022-04-25.fits', '/data/user/fmcnally/anisotropy/maps/IC86-2021/IC86-2021_24H_solar_2022-04-26.fits', '/data/user/fmcnally/anisotropy/maps/IC86-2021/IC86-2021_24H_solar_2022-04-27.fits', '/data/user/fmcnally/anisotropy/maps/IC86-2021/IC86-2021_24H_solar_2022-04-28.fits', '/data/user/fmcnally/anisotropy/maps/IC86-2021/IC86-2021_24H_solar_2022-04-29.fits', '/data/user/fmcnally/anisotropy/maps/IC86-2021/IC86-2021_24H_solar_2022-04-30.fits']

# %%
m = getMap(solar_maps, mapName='signal', smooth=5, verbose=False, mask=True)

# %%
hp.mollview(m)
plt.show()

# %% [markdown]
# May

# %%
# Test for significance plot
map_location = '/data/user/fmcnally/anisotropy/maps/IC86-2021'
solar_maps = sorted(glob(f'{map_location}/*solar_????-05-??.fits'))
# print(solar_maps)

# %%
m = getMap(solar_maps, mapName='signal', smooth=5, verbose=False, mask=True)

# %%
hp.mollview(m)
plt.show()

# %% [markdown]
# June

# %%
# Test for significance plot
map_location = '/data/user/fmcnally/anisotropy/maps/IC86-2021'
solar_maps = sorted(glob(f'{map_location}/*solar_????-06-??.fits'))
# print(solar_maps)

# %%
m = getMap(solar_maps, mapName='signal', smooth=5, verbose=False, mask=True)

# %%
hp.mollview(m)
plt.show()

# %% [markdown]
# July

# %%
# Test for significance plot
map_location = '/data/user/fmcnally/anisotropy/maps/IC86-2021'
solar_maps = sorted(glob(f'{map_location}/*solar_????-07-??.fits'))
# print(solar_maps)

# %%
m = getMap(solar_maps, mapName='signal', smooth=5, verbose=False, mask=True)

# %%
hp.mollview(m)
plt.show()

# %% [markdown]
# August

# %%
# Test for significance plot
map_location = '/data/user/fmcnally/anisotropy/maps/IC86-2021'
solar_maps = sorted(glob(f'{map_location}/*solar_????-08-??.fits'))
# print(solar_maps)

# %%
m = getMap(solar_maps, mapName='signal', smooth=5, verbose=False, mask=True)

# %%
hp.mollview(m)
plt.show()

# %% [markdown]
# September

# %%
# Test for significance plot
map_location = '/data/user/fmcnally/anisotropy/maps/IC86-2021'
solar_maps = sorted(glob(f'{map_location}/*solar_????-09-??.fits'))
# print(solar_maps)

# %%
m = getMap(solar_maps, mapName='signal', smooth=5, verbose=False, mask=True)

# %%
hp.mollview(m)
plt.show()

# %% [markdown]
# October

# %%
# Test for significance plot
map_location = '/data/user/fmcnally/anisotropy/maps/IC86-2021'
solar_maps = sorted(glob(f'{map_location}/*solar_????-10-??.fits'))
# print(solar_maps)

# %%
m = getMap(solar_maps, mapName='signal', smooth=5, verbose=False, mask=True)

# %%
hp.mollview(m)
plt.show()

# %% [markdown]
# November

# %%
# Test for significance plot
map_location = '/data/user/fmcnally/anisotropy/maps/IC86-2021'
solar_maps = sorted(glob(f'{map_location}/*solar_????-11-??.fits'))
# print(solar_maps)

# %%
m = getMap(solar_maps, mapName='signal', smooth=5, verbose=False, mask=True)

# %%
hp.mollview(m)
plt.show()

# %% [markdown]
# December

# %%
# Test for significance plot
map_location = '/data/user/fmcnally/anisotropy/maps/IC86-2021'
solar_maps = sorted(glob(f'{map_location}/*solar_????-12-??.fits'))
# print(solar_maps)

# %%
m = getMap(solar_maps, mapName='signal', smooth=5, verbose=False, mask=True)

# %%
hp.mollview(m)
plt.show()

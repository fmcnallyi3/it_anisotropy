# %%
import healpy as hp
import numpy as np
import matplotlib.pyplot as plt

from glob import glob

from mapFunctions import getMap

# %%
# All months will be in displayed with a 'signal' map type

# %% [markdown]
# Map for 2019 (all months combined)

# %%
# Test for significance plot
map_location = '/data/user/fmcnally/anisotropy/maps/IC86-2019'
# for month in range(13):
solar_maps = sorted(glob(f'{map_location}/*solar_????-{month}-??.fits'))
m = getMap(solar_maps, mapName='signal', smooth=5, verbose=False, mask=True)
hp.mollview(m)
plt.show()
# print(solar_maps)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-30-246df72bba9f> in <module>
#       2 map_location = '/data/user/fmcnally/anisotropy/maps/IC86-2019'
#       3 # for month in range(13):
# ----> 4 solar_maps = sorted(glob(f'{map_location}/*solar_????-{month}-??.fits'))
#       5 m = getMap(solar_maps, mapName='signal', smooth=5, verbose=False, mask=True)
#       6 hp.mollview(m)
#
# NameError: name 'month' is not defined

# %% [markdown]
# January

# %%
# Test for significance plot
map_location = '/data/user/fmcnally/anisotropy/maps/IC86-2019'
solar_maps = sorted(glob(f'{map_location}/*solar_????-01-??.fits'))
# print(solar_maps)

# %%
m = getMap(solar_maps, mapName='signal', smooth=5, verbose=False, mask=True)

# %%
hp.mollview(m)
plt.show()

# %% [markdown]
# February

# %%
# Test for significance plot
map_location = '/data/user/fmcnally/anisotropy/maps/IC86-2019'
solar_maps = sorted(glob(f'{map_location}/*solar_????-02-??.fits'))
# print(solar_maps)

# %%
m = getMap(solar_maps, mapName='signal', smooth=5, verbose=False, mask=True)

# %%
hp.mollview(m)
plt.show()

# %% [markdown]
# March

# %%
# Test for significance plot
map_location = '/data/user/fmcnally/anisotropy/maps/IC86-2019'
solar_maps = sorted(glob(f'{map_location}/*solar_????-03-??.fits'))
# print(solar_maps)

# %%
m = getMap(solar_maps, mapName='signal', smooth=5, verbose=False, mask=True)

# %%
hp.mollview(m)
plt.show()

# %% [markdown]
# April

# %%
# Test for significance plot
map_location = '/data/user/fmcnally/anisotropy/maps/IC86-2019'
solar_maps = sorted(glob(f'{map_location}/*solar_????-04-??.fits'))
# print(solar_maps)

# %%
m = getMap(solar_maps, mapName='signal', smooth=5, verbose=False, mask=True)

# %%
hp.mollview(m)
plt.show()

# %% [markdown]
# May

# %%
# Test for significance plot
map_location = '/data/user/fmcnally/anisotropy/maps/IC86-2019'
solar_maps = sorted(glob(f'{map_location}/*solar_????-05-??.fits'))
print(solar_maps)
# Out:
# ['/data/user/fmcnally/anisotropy/maps/IC86-2019/IC86-2019_24H_solar_2020-05-01.fits', '/data/user/fmcnally/anisotropy/maps/IC86-2019/IC86-2019_24H_solar_2020-05-02.fits', '/data/user/fmcnally/anisotropy/maps/IC86-2019/IC86-2019_24H_solar_2020-05-03.fits', '/data/user/fmcnally/anisotropy/maps/IC86-2019/IC86-2019_24H_solar_2020-05-04.fits', '/data/user/fmcnally/anisotropy/maps/IC86-2019/IC86-2019_24H_solar_2020-05-06.fits', '/data/user/fmcnally/anisotropy/maps/IC86-2019/IC86-2019_24H_solar_2020-05-07.fits', '/data/user/fmcnally/anisotropy/maps/IC86-2019/IC86-2019_24H_solar_2020-05-08.fits', '/data/user/fmcnally/anisotropy/maps/IC86-2019/IC86-2019_24H_solar_2020-05-09.fits', '/data/user/fmcnally/anisotropy/maps/IC86-2019/IC86-2019_24H_solar_2020-05-10.fits', '/data/user/fmcnally/anisotropy/maps/IC86-2019/IC86-2019_24H_solar_2020-05-11.fits', '/data/user/fmcnally/anisotropy/maps/IC86-2019/IC86-2019_24H_solar_2020-05-12.fits', '/data/user/fmcnally/anisotropy/maps/IC86-2019/IC86-2019_24H_solar_2020-05-13.fits', '/data/user/fmcnally/anisotropy/maps/IC86-2019/IC86-2019_24H_solar_2020-05-14.fits', '/data/user/fmcnally/anisotropy/maps/IC86-2019/IC86-2019_24H_solar_2020-05-15.fits', '/data/user/fmcnally/anisotropy/maps/IC86-2019/IC86-2019_24H_solar_2020-05-16.fits', '/data/user/fmcnally/anisotropy/maps/IC86-2019/IC86-2019_24H_solar_2020-05-17.fits', '/data/user/fmcnally/anisotropy/maps/IC86-2019/IC86-2019_24H_solar_2020-05-18.fits', '/data/user/fmcnally/anisotropy/maps/IC86-2019/IC86-2019_24H_solar_2020-05-19.fits', '/data/user/fmcnally/anisotropy/maps/IC86-2019/IC86-2019_24H_solar_2020-05-20.fits', '/data/user/fmcnally/anisotropy/maps/IC86-2019/IC86-2019_24H_solar_2020-05-21.fits', '/data/user/fmcnally/anisotropy/maps/IC86-2019/IC86-2019_24H_solar_2020-05-22.fits', '/data/user/fmcnally/anisotropy/maps/IC86-2019/IC86-2019_24H_solar_2020-05-23.fits', '/data/user/fmcnally/anisotropy/maps/IC86-2019/IC86-2019_24H_solar_2020-05-24.fits', '/data/user/fmcnally/anisotropy/maps/IC86-2019/IC86-2019_24H_solar_2020-05-25.fits', '/data/user/fmcnally/anisotropy/maps/IC86-2019/IC86-2019_24H_solar_2020-05-26.fits', '/data/user/fmcnally/anisotropy/maps/IC86-2019/IC86-2019_24H_solar_2020-05-27.fits', '/data/user/fmcnally/anisotropy/maps/IC86-2019/IC86-2019_24H_solar_2020-05-28.fits', '/data/user/fmcnally/anisotropy/maps/IC86-2019/IC86-2019_24H_solar_2020-05-29.fits']

# %%
m = getMap(solar_maps, mapName='signal', smooth=5, verbose=False, mask=True)

# %%
hp.mollview(m)
plt.show()

# %% [markdown]
# June

# %%
# Test for significance plot
map_location = '/data/user/fmcnally/anisotropy/maps/IC86-2019'
solar_maps = sorted(glob(f'{map_location}/*solar_????-06-??.fits'))
print(solar_maps)
# Out:
# []

# %%
m = getMap(solar_maps, mapName='signal', smooth=5, verbose=False, mask=True)
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-76-eb018b34e6ad> in <module>
# ----> 1 m = getMap(solar_maps, mapName='signal', smooth=5, verbose=False, mask=True)
#
# ~/IceCube/mapFunctions.py in getMap(inFiles, mapName, multi, smooth, stype, swindow, verbose, mask, decmin, decmax, fix_multi, alpha, **kwargs)
#     432         decmax = -25.
#     433         decmin = -90.
# --> 434         if os.path.basename(inFiles[0])[:2] == 'IT':
#     435             decmax = -35.
#     436
#
# IndexError: list index out of range

# %%
hp.mollview(m)
plt.show()

# %% [markdown]
# July

# %%
# Test for significance plot
map_location = '/data/user/fmcnally/anisotropy/maps/IC86-2019'
solar_maps = sorted(glob(f'{map_location}/*solar_????-07-??.fits'))
# print(solar_maps)

# %%
m = getMap(solar_maps, mapName='signal', smooth=5, verbose=False, mask=True)

# %%
hp.mollview(m)
plt.show()

# %% [markdown]
# August

# %%
# Test for significance plot
map_location = '/data/user/fmcnally/anisotropy/maps/IC86-2019'
solar_maps = sorted(glob(f'{map_location}/*solar_????-08-??.fits'))
# print(solar_maps)

# %%
m = getMap(solar_maps, mapName='signal', smooth=5, verbose=False, mask=True)

# %%
hp.mollview(m)
plt.show()

# %% [markdown]
# September

# %%
# Test for significance plot
map_location = '/data/user/fmcnally/anisotropy/maps/IC86-2019'
solar_maps = sorted(glob(f'{map_location}/*solar_????-09-??.fits'))
# print(solar_maps)

# %%
m = getMap(solar_maps, mapName='signal', smooth=5, verbose=False, mask=True)

# %%
hp.mollview(m)
plt.show()

# %% [markdown]
# October

# %%
# Test for significance plot
map_location = '/data/user/fmcnally/anisotropy/maps/IC86-2019'
solar_maps = sorted(glob(f'{map_location}/*solar_????-10-??.fits'))
# print(solar_maps)

# %%
m = getMap(solar_maps, mapName='signal', smooth=5, verbose=False, mask=True)

# %%
hp.mollview(m)
plt.show()

# %% [markdown]
# November

# %%
# Test for significance plot
map_location = '/data/user/fmcnally/anisotropy/maps/IC86-2019'
solar_maps = sorted(glob(f'{map_location}/*solar_????-11-??.fits'))
# print(solar_maps)

# %%
m = getMap(solar_maps, mapName='signal', smooth=5, verbose=False, mask=True)

# %%
hp.mollview(m)
plt.show()

# %% [markdown]
# December

# %%
# Test for significance plot
map_location = '/data/user/fmcnally/anisotropy/maps/IC86-2019'
solar_maps = sorted(glob(f'{map_location}/*solar_????-12-??.fits'))
# print(solar_maps)

# %%
m = getMap(solar_maps, mapName='signal', smooth=5, verbose=False, mask=True)

# %%
hp.mollview(m)
plt.show()

# %%
import healpy as hp
import numpy as np
import matplotlib.pyplot as plt

from glob import glob

from mapFunctions import getMap

# %% [markdown]
# ## First plotting test

# %%
# Test for significance plot
map_location = '/data/user/fmcnally/anisotropy/maps/merged'
solar_maps = sorted(glob(f'{map_location}/*solar.fits'))
# print(solar_maps)

# %%
map_file = solar_maps[-1]
m = getMap([map_file], mapName='signal', smooth=5, verbose=False, mask=True)

# %%
# hp.mollview(m)
# plt.show()

# %% [markdown]
# ## Grouping files test

# %%
# Test for significance plot
map_location = '/data/user/fmcnally/anisotropy/maps/IC86-2012'
solar_maps = sorted(glob(f'{map_location}/*solar_????-01-??.fits'))
# print(solar_maps)

# %%
m = getMap(solar_maps, mapName='signal', smooth=5, verbose=False, mask=True)

# %%
hp.mollview(m)
plt.show()

# %%
# ??: can you do this for one month, but ALL years in one plot
# ??: can you extrapolate to one plot per month

# %%
# Test for significance plot
map_location = '/data/user/fmcnally/anisotropy/maps'
solar_october_maps = sorted(glob(f'{map_location}/IC86-20??/*solar_????-10-??.fits'))
#print(solar_october)

# %%
m = getMap(solar_october_maps, mapName='relint', smooth=5, verbose=False, mask=True)

# %%
hp.mollview(m)
plt.show()

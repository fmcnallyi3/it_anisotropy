# %%
import healpy as hp
import numpy as np
import matplotlib.pyplot as plt

from glob import glob

from mapFunctions import getMap

# %%
# show how maps change over time either with python or with a gif animator online

# %%
# All months will be in displayed with a 'signal' map type

# %% [markdown]
# Map for 2012 (all months combined)

# %%
# # Test for significance plot
# map_location = '/data/user/fmcnally/anisotropy/maps/maps_12yr_smt08/IC86-2012'
# for month in range(1,13):
#     solar_maps = sorted(glob(f'{map_location}/*solar_????-{month}-??.fits'))
#     m = getMap(solar_maps, mapName='signal', smooth=5, verbose=False, mask=True)
# hp.mollview(m)
# plt.show()

# # Test for significance plot
# map_location = '/data/user/fmcnally/anisotropy/maps/maps_12yr_smt08/IC86-2012'
# for month in range(1,13):
#     solar_maps = sorted(glob(f'{map_location}/*solar_????-{month}-??.fits'))
#     m = getMap(solar_maps, mapName='signal', smooth=5, verbose=False, mask=True)
#     hp.mollview(m)
#     plt.show()

#why do lines 5-7 need to be in seperate cells? why won't it work if it is in the same cell
#what is the difference between the two sets of code above?

# %%
# Test for significance plot
map_location = '/data/user/fmcnally/anisotropy/maps/maps_12yr_smt08/IC86-2012'
solar_maps = {}
months = [f'{i:>02}' for i in range(1,13)] # > pad [01 02 03 04 .. 09 10 11 12]
for month in months:
    solar_maps[month] = sorted(glob(f'{map_location}/*solar_????-{month}-??.fits'))

# %%
m = getMap(solar_maps['01'], mapName='signal', smooth=5, verbose=False, mask=True)

# %%
hp.mollview(m)
plt.show()

# %% [markdown]
# January

# %%
# Test for significance plot
map_location = '/data/user/fmcnally/anisotropy/maps/maps_12yr_smt08/IC86-2012'
solar_maps = sorted(glob(f'{map_location}/*solar_????-01-??.fits'))

# %%
m = getMap(solar_maps, mapName='signal', smooth=5, verbose=False, mask=True)

# %%
hp.mollview(m)
plt.show()

# %% [markdown]
# February

# %%
# Test for significance plot
map_location = '/data/user/fmcnally/anisotropy/maps/maps_12yr_smt08/IC86-2012'
solar_maps = sorted(glob(f'{map_location}/*solar_????-02-??.fits'))
# print(solar_maps)

# %%
m = getMap(solar_maps, mapName='signal', smooth=5, verbose=False, mask=True)

# %%
hp.mollview(m)
plt.show()

# %% [markdown]
# March

# %%
# Test for significance plot
map_location = '/data/user/fmcnally/anisotropy/maps/maps_12yr_smt08/IC86-2012'
solar_maps = sorted(glob(f'{map_location}/*solar_????-03-??.fits'))
# print(solar_maps)

# %%
m = getMap(solar_maps, mapName='signal', smooth=5, verbose=False, mask=True)

# %%
hp.mollview(m)
plt.show()

# %% [markdown]
# April

# %%
# Test for significance plot
map_location = '/data/user/fmcnally/anisotropy/maps/maps_12yr_smt08/IC86-2012'
solar_maps = sorted(glob(f'{map_location}/*solar_????-04-??.fits'))
# print(solar_maps)

# %%
m = getMap(solar_maps, mapName='signal', smooth=5, verbose=False, mask=True)

# %%
hp.mollview(m)
plt.show()

# %% [markdown]
# May

# %%
# Test for significance plot
map_location = '/data/user/fmcnally/anisotropy/maps/maps_12yr_smt08/IC86-2012'
solar_maps = sorted(glob(f'{map_location}/*solar_????-05-??.fits'))
# print(solar_maps)

# %%
m = getMap(solar_maps, mapName='signal', smooth=5, verbose=False, mask=True)

# %%
hp.mollview(m)
plt.show()

# %% [markdown]
# June

# %%
# Test for significance plot
map_location = '/data/user/fmcnally/anisotropy/maps/maps_12yr_smt08/IC86-2012'
solar_maps = sorted(glob(f'{map_location}/*solar_????-06-??.fits'))
# print(solar_maps)

# %%
m = getMap(solar_maps, mapName='signal', smooth=5, verbose=False, mask=True)

# %%
hp.mollview(m)
plt.show()

# %% [markdown]
# July

# %%
# Test for significance plot
map_location = '/data/user/fmcnally/anisotropy/maps/maps_12yr_smt08/IC86-2012'
solar_maps = sorted(glob(f'{map_location}/*solar_????-07-??.fits'))
# print(solar_maps)

# %%
m = getMap(solar_maps, mapName='signal', smooth=5, verbose=False, mask=True)

# %%
hp.mollview(m)
plt.show()

# %% [markdown]
# August

# %%
# Test for significance plot
map_location = '/data/user/fmcnally/anisotropy/maps/maps_12yr_smt08/IC86-2012'
solar_maps = sorted(glob(f'{map_location}/*solar_????-08-??.fits'))
# print(solar_maps)

# %%
m = getMap(solar_maps, mapName='signal', smooth=5, verbose=False, mask=True)

# %%
hp.mollview(m)
plt.show()

# %% [markdown]
# September

# %%
# Test for significance plot
map_location = '/data/user/fmcnally/anisotropy/maps/maps_12yr_smt08/IC86-2012'
solar_maps = sorted(glob(f'{map_location}/*solar_????-09-??.fits'))
# print(solar_maps)

# %%
m = getMap(solar_maps, mapName='signal', smooth=5, verbose=False, mask=True)

# %%
hp.mollview(m)
plt.show()

# %% [markdown]
# October

# %%
# Test for significance plot
map_location = '/data/user/fmcnally/anisotropy/maps/maps_12yr_smt08/IC86-2012'
solar_maps = sorted(glob(f'{map_location}/*solar_????-10-??.fits'))
# print(solar_maps)

# %%
m = getMap(solar_maps, mapName='signal', smooth=5, verbose=False, mask=True)

# %%
hp.mollview(m)
plt.show()

# %% [markdown]
# November

# %%
# Test for significance plot
map_location = '/data/user/fmcnally/anisotropy/maps/maps_12yr_smt08/IC86-2012'
solar_maps = sorted(glob(f'{map_location}/*solar_????-11-??.fits'))
# print(solar_maps)

# %%
m = getMap(solar_maps, mapName='signal', smooth=5, verbose=False, mask=True)

# %%
hp.mollview(m)
plt.show()

# %% [markdown]
# December

# %%
# Test for significance plot
map_location = '/data/user/fmcnally/anisotropy/maps/maps_12yr_smt08/IC86-2012'
solar_maps = sorted(glob(f'{map_location}/*solar_????-12-??.fits'))
# print(solar_maps)

# %%
m = getMap(solar_maps, mapName='signal', smooth=5, verbose=False, mask=True)

# %%
hp.mollview(m)
plt.show()

# %%
import healpy as hp
import numpy as np
import matplotlib.pyplot as plt

from glob import glob

from mapFunctions import getMap

# %%
# All months will be in displayed with a 'data' map type

# %% [markdown]
# January

# %%
# Test for significance plot
for year in range(12, 23): # Goes to 22 but does not include 23
    map_location = f'/data/user/fmcnally/anisotropy/maps/maps_12yr_smt08/IC86-20{year}'
    solar_maps = sorted(glob(f'{map_location}/*sid_????-01-??.fits'))
# print(solar_maps)

# %%
m = getMap(solar_maps, mapName='data', smooth=5, verbose=False, mask=True)

# %%
hp.mollview(m, min=-7, max=7, title="January")
plt.show()

# %%
# Test for significance plot
for year in range(12, 23): # Goes to 22 but does not include 23
    map_location = f'/data/user/fmcnally/anisotropy/maps/maps_12yr_smt08/IC86-20{year}'
    solar_maps = sorted(glob(f'{map_location}/*solar_????-01-??.fits'))
# print(solar_maps)

# %%
m = getMap(solar_maps, mapName='data', smooth=5, verbose=False, mask=True)

# %%
hp.mollview(m, min=-7, max=7, title="January")
plt.show()

# %% [markdown]
# February

# %%
# Test for significance plot
for year in range(12, 23): # Goes to 22 but does not include 23
    map_location = f'/data/user/fmcnally/anisotropy/maps/maps_12yr_smt08/IC86-20{year}'
    solar_maps = sorted(glob(f'{map_location}/*solar_????-02-??.fits'))
# print(solar_maps)

# %%
m = getMap(solar_maps, mapName='data', smooth=5, verbose=False, mask=True)

# %%
hp.mollview(m, min=-7 , max=7, title="February")
plt.show()

# %% [markdown]
# March

# %%
# Test for significance plot
for year in range(12, 23): # Goes to 22 but does not include 23
    map_location = f'/data/user/fmcnally/anisotropy/maps/maps_12yr_smt08/IC86-20{year}'
    solar_maps = sorted(glob(f'{map_location}/*solar_????-03-??.fits'))
# print(solar_maps)

# %%
m = getMap(solar_maps, mapName='data', smooth=5, verbose=False, mask=True)

# %%
hp.mollview(m, min=-7 , max=7, title="March")
plt.show()

# %% [markdown]
# April

# %%
# Test for significance plot
for year in range(12, 23): # Goes to 22 but does not include 23
    map_location = f'/data/user/fmcnally/anisotropy/maps/maps_12yr_smt08/IC86-20{year}'
    solar_maps = sorted(glob(f'{map_location}/*solar_????-04-??.fits'))
# print(solar_maps)

# %%
m = getMap(solar_maps, mapName='data', smooth=5, verbose=False, mask=True)

# %%
hp.mollview(m, min=-7, max=7, title="April")
plt.show()

# %% [markdown]
# May

# %%
# Test for significance plot
for year in range(12, 23): # Goes to 22 but does not include 23
    map_location = f'/data/user/fmcnally/anisotropy/maps/maps_12yr_smt08/IC86-20{year}'
    solar_maps = sorted(glob(f'{map_location}/*solar_????-05-??.fits'))
# print(solar_maps)

# %%
m = getMap(solar_maps, mapName='data', smooth=5, verbose=False, mask=True)

# %%
hp.mollview(m, min=-7, max=7, title="May")
plt.show()

# %% [markdown]
# June

# %%
# Test for significance plot
for year in range(12, 23): # Goes to 22 but does not include 23
    map_location = f'/data/user/fmcnally/anisotropy/maps/maps_12yr_smt08/IC86-20{year}'
    solar_maps = sorted(glob(f'{map_location}/*solar_????-06-??.fits'))
# print(solar_maps)

# %%
m = getMap(solar_maps, mapName='data', smooth=5, verbose=False, mask=True)

# %%
hp.mollview(m, min=-7, max=7, title="June")
plt.show()

# %% [markdown]
# July

# %%
# Test for significance plot
for year in range(12, 23): # Goes to 22 but does not include 23
    map_location = f'/data/user/fmcnally/anisotropy/maps/maps_12yr_smt08/IC86-20{year}'
    solar_maps = sorted(glob(f'{map_location}/*solar_????-07-??.fits'))
# print(solar_maps)

# %%
m = getMap(solar_maps, mapName='data', smooth=5, verbose=False, mask=True)

# %%
hp.mollview(m, min=-7, max=7, title="July")
plt.show()

# %%
# Test for significance plot
for year in range(12, 23): # Goes to 22 but does not include 23
    map_location = f'/data/user/fmcnally/anisotropy/maps/maps_12yr_smt08/IC86-20{year}'
    solar_maps = sorted(glob(f'{map_location}/*solar_????-07-??.fits'))
# print(solar_maps)

# %%
m = getMap(solar_maps, mapName='relint', smooth=5, verbose=False, mask=True)

# %%
hp.mollview(m, min=-0.001, max=0.001, title=" ")
plt.show()

# %% [markdown]
# August

# %%
# Test for significance plot
for year in range(12, 23): # Goes to 22 but does not include 23
    map_location = f'/data/user/fmcnally/anisotropy/maps/maps_12yr_smt08/IC86-20{year}'
    solar_maps = sorted(glob(f'{map_location}/*solar_????-08-??.fits'))
# print(solar_maps)

# %%
m = getMap(solar_maps, mapName='data', smooth=5, verbose=False, mask=True)

# %%
hp.mollview(m, min=-7, max=7, title="August")
plt.show()

# %% [markdown]
# September

# %%
# Test for significance plot
for year in range(12, 23): # Goes to 22 but does not include 23
    map_location = f'/data/user/fmcnally/anisotropy/maps/maps_12yr_smt08/IC86-20{year}'
    solar_maps = sorted(glob(f'{map_location}/*solar_????-09-??.fits'))
# print(solar_maps)

# %%
m = getMap(solar_maps, mapName='data', smooth=5, verbose=False, mask=True)

# %%
hp.mollview(m, min=-7, max=7, title="September")
plt.show()

# %% [markdown]
# October

# %%
# Test for significance plot
for year in range(12, 23): # Goes to 22 but does not include 23
    map_location = f'/data/user/fmcnally/anisotropy/maps/maps_12yr_smt08/IC86-20{year}'
    solar_maps = sorted(glob(f'{map_location}/*solar_????-10-??.fits'))
# print(solar_maps)

# %%
m = getMap(solar_maps, mapName='data', smooth=5, verbose=False, mask=True)

# %%
hp.mollview(m, min=-7, max=7, title="October")
plt.show()

# %% [markdown]
# November

# %%
# Test for significance plot
for year in range(12, 23): # Goes to 22 but does not include 23
    map_location = f'/data/user/fmcnally/anisotropy/maps/maps_12yr_smt08/IC86-20{year}'
    solar_maps = sorted(glob(f'{map_location}/*solar_????-11-??.fits'))
# print(solar_maps)

# %%
m = getMap(solar_maps, mapName='data', smooth=5, verbose=False, mask=True)

# %%
hp.mollview(m, min=-7, max=7, title="November")
plt.show()

# %% [markdown]
# December

# %%
# Test for significance plot
for year in range(12, 23): # Goes to 22 but does not include 23
    map_location = f'/data/user/fmcnally/anisotropy/maps/maps_12yr_smt08/IC86-20{year}'
    solar_maps = sorted(glob(f'{map_location}/*solar_????-12-??.fits'))
# print(solar_maps)

# %%
m = getMap(solar_maps, mapName='data', smooth=5, verbose=False, mask=True)

# %%
hp.mollview(m, min=-7, max=7, title="December")
plt.show()

# %%
# ALL

# %%
# Test for significance plot
for year in range(12, 23): # Goes to 22 but does not include 23
    map_location = f'/data/user/fmcnally/anisotropy/maps/maps_12yr_smt08/IC86-20{year}'
    solar_maps = sorted(glob(f'{map_location}/*solar_????-??-??.fits'))
# print(solar_maps)

# %%
m = getMap(solar_maps, mapName='data', smooth=5, verbose=False, mask=True)

# %%
hp.mollview(m, min=-7 , max=7, title='')
plt.show()

# %%
# Test for significance plot
for year in range(12, 23): # Goes to 22 but does not include 23
    map_location = f'/data/user/fmcnally/anisotropy/maps/maps_12yr_smt08/IC86-20{year}'
    solar_maps = sorted(glob(f'{map_location}/*solar_????-??-??.fits'))
# print(solar_maps)

# %%
m = getMap(solar_maps, mapName='relint', smooth=5, verbose=False, mask=True)

# %%
hp.mollview(m, min=-0.0005 , max=0.0005, title='All Months Combined')
plt.show()

# %%
# Test for significance plot
for year in range(12, 23): # Goes to 22 but does not include 23
    map_location = f'/data/user/fmcnally/anisotropy/maps/maps_12yr_smt08/IC86-20{year}'
    solar_maps = sorted(glob(f'{map_location}/*solar_????-??-??.fits'))
# print(solar_maps)

# %%
m = getMap(solar_maps, mapName='relint', smooth=5, verbose=False, mask=True)

# %%
hp.mollview(m, min=-0.001 , max=0.001, title='All Months Combined')
plt.show()

# %%
hp.mollview?
# Out:
# Signature:
# hp.mollview(
#     map=None,
#     fig=None,
#     rot=None,
#     coord=None,
#     unit='',
#     xsize=800,
#     title='Mollweide view',
#     nest=False,
#     min=None,
#     max=None,
#     flip='astro',
#     remove_dip=False,
#     remove_mono=False,
#     gal_cut=0,
#     format='%g',
#     format2='%g',
#     cbar=True,
#     cmap=None,
#     badcolor='gray',
#     bgcolor='white',
#     notext=False,
#     norm=None,
#     hold=False,
#     margins=None,
#     sub=None,
#     nlocs=2,
#     return_projected_map=False,
# )
# Docstring:
# Plot a healpix map (given as an array) in Mollweide projection.
#
# Parameters
# ----------
# map : float, array-like or None
#   An array containing the map, supports masked maps, see the `ma` function.
#   If None, will display a blank map, useful for overplotting.
# fig : int or None, optional
#   The figure number to use. Default: create a new figure
# rot : scalar or sequence, optional
#   Describe the rotation to apply.
# ...

# %%
plt.show?
# Out:
# Signature: plt.show(*args, **kw)
# Docstring:
# Display a figure.
# When running in ipython with its pylab mode, display all
# figures and return to the ipython prompt.
#
# In non-interactive mode, display all figures and block until
# the figures have been closed; in interactive mode it has no
# effect unless figures were created prior to a change from
# non-interactive to interactive mode (not recommended).  In
# that case it displays the figures but does not block.
#
# A single experimental keyword argument, *block*, may be
# set to True or False to override the blocking behavior
# described above.
# File:      /cvmfs/icecube.opensciencegrid.org/py3-v4.1.1/Ubuntu_20.04_x86_64/lib/python3.7/site-packages/matplotlib/pyplot.py
# Type:      function
